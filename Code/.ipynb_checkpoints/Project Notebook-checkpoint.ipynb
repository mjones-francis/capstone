# %% [markdown]
# # Predicting NBA Salaries to Help Players and Agents

# %% [markdown]
# ### Author: Markell Jones-Francis [(Github)](https://github.com/mjones-francis), [(LinkedIn)](https://www.linkedin.com/in/markell-jones-francis/)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# NBA Salary negotiations are complicated. They require a multitude of stakeholders, each with their own agendas and interests, coming together to agree on a contract with a set number of years and often a guaranteed salary. Players and agents look to maximize their earnings by signing for the most amount they can, while General Managers will often try to keep numbers manageable so they have room to continue signing more players without exceeding the league-mandated salary cap.
#
# The issue at the heart of these negotiations is the player's statistical performance. While outside factors such as interpersonal relationships and star power play a role, the statistics that a player is able to record while playing and their ability to help their team matter more than any other factor when negotiating a contract. To streamline this process for players and agents, we will be building a machine learning model using each player's basic, advanced, and team statistics in order to accurately predict their salary. To do this we will be using Linear Regression, Lasso, Ridge, Decision Tree, Random Forest, and Neural Network models and, given the scale of NBA contracts, will be looking to make predictions that are accurate within \\$2,000,000 per year, using RMSE as our metric.
#
# We will be using data from the 2016-17 to the 2018-19 seasons for these projections, because the 2016-17 season saw the NBA salary cap increase to \\$94M, from \\$70M the season before, as a result of the NBA's then newly signed television deal which brought in additional revenue. This cap increase resulted in salary increases across the board for NBA players, so much so that any salaries 2016-17 bear little comparative value when evaluating statistical performance. We are also ending the analysis at the 2018-19 season as that is the most recent completed NBA season.
#
# With this tool we hope to assist agents find the most fair salaries for the players they represent, and determine which teams are most likely pay their clients the salary that they deserve.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# Before we could any of our analysis or modeling, we first had to gather our data. After much searching, we decided to use Basketball Reference for our Basic and Advanced Statistics, ESPN for our Team Statistics, and Hoops Hype for our salary data. One hurdle we came across during the data gathering phase, was that several potential sources of useful data, had said data commented out in source code of the web page - though whether this was an oversight or an intentional move to block scraping is unclear. Once we finalized our data sources, we used the BeautifulSoup4 Python package to scrape the tables of the appropriate web pages and import the information and combined each data source into one master dataframe, merged on Player, Team, and Season. The full data gathering process can be found in the Data Gathering folder of this repo.
#
# Once our data hand was in hand and cleaned we were able to begin our analysis. Our analysis proved some of our initial assumptions to be true, it also offered many surprises, and this all began by visualizing the correlation between our various features and our target variable, Salary. We knew before the analysis began that scoring and statistics related to scoring would be highly correlated to Salary - the NBA is an on offense-driven league after all. But what caught us off-guard was the relatively limited correlation that many advanved stats had to Salary. For all the discourse surrounding the modern NBA and the importance of analytics, many of the advanced statistics basketball afficianados obsess over had little correlation to how much a team was willing to pay a player.  But we also understood that correlation is not the same as causation so were delved deeper.
#
# After additional analysis we began our initial attempt at modeling which could only be described as an absolute failure. We tested dozens of combinations on each our models and each one returned testing predictions that were off by an average at least $6 Million. We realized that a large part of this was due to younger players whose performance would suggest a high contract value, but whose earnings were limited by NBA policy regarding recently drafted players. While we knew before we began that the intricacies of NBA contracts would have an effect on our analysis and our models' ability to generate predictions, we had hoped that these would be accounted for by the relationships between various features in our data. We were wrong.
#
# We then went back to our analysis in order to find a way to account for these changes. Understanding the importance that age had on a players salary, we knew we had to find a way to make our model understand that younger players were limited to a certain salary range, but also that players are not playerd more simply because they are older. We opted to do this by K-Means Clustering in order segment our data set into distinct groups of players, so our models could more easily distinguish between high and low earners. The end result was a final model that, while not perfect, offered a significant improvement over our initial efforts allowed us to gain actionable insights moving forward.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * [Loading Data](#Loading-Data)
#     * [Library Imports](#Library-Imports)
#     * [Data Imports](#Data-Imports)
# * [Data Dictionary](#Data-Dictionary)
# * [Data Cleaning](#Data-Cleaning)
# * [(Feature Engineering)](#Feature-Engineering)
# * [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#     * [Distribution of Target Variable](#Distribution-of-Target-Variable)
#     * [Correlation Analysis](#Correlation-Analysis)
#     * [Season Analysis](#Season-Analysis)
#     * [Age Analysis](#Age_Analysis)
#     * [Team and Position Analysis](#Team-and-Position-Analysis)
# * [Clustering](#Clustering)
# * [Model Preparation](#Model-Prepartion)
#     * [Dummifying Columns](#Dummifying-Columns)
#     * [RMSE Functions](#RMSE-Functions)
#     * [Feature Sets](#Feature-Sets)
# * [Modeling](#Modeling)
#     * [Baseline Model](#Baseline-Model)
#     * [Linear Regression](#Linear-Regression)
#     * [Ridge Regression](#Ridge-Regression)
#     * [Lasso Regression](#Lasso-Regression)
#     * [K Nearest Neighbors](#K-Nearest-Neighbors)
#     * [Decision Tree](#Decision-Tree)
#     * [Random Forest](#Random-Forest)
#     * [Support Vector Machine](#Support-Vector-Machine)
# * [Model Selection](#Model-Selection)
# * [Model Evaluation](#Model-Evaluation)
# * [Prediction Analysis](#Prediction-Analysis)
# * [Conclusion](#Conclusion)
# * [References](#References)

# %% [markdown]
# ## Loading Data

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm  import SVR
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import r2_score, mean_squared_error, silhouette_score, make_scorer


RANDOM_STATE = 999
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\mjone\anaconda3\envs\dsi\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = "{:f}".format

# %% [markdown]
# ### Data Imports

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
data = pd.read_csv('../Data/nba_data.csv')
df = data.copy()
df.head()
# Out:
#            player pos  age team_id   g  gs  mp_per_g  fg_per_g  fga_per_g  \
# 0    Alex Abrines  SG   23     OKC  68   6 15.500000  2.000000   5.000000
# 1    Steven Adams   C   23     OKC  80  80 29.900000  4.700000   8.200000
# 2  Semaj Christon  PG   24     OKC  64   1 15.200000  1.200000   3.500000
# 3     Norris Cole  PG   28     OKC  13   0  9.600000  1.200000   4.000000
# 4   Nick Collison  PF   36     OKC  20   0  6.400000  0.700000   1.200000
#
#     fg_pct  fg3_per_g  fg3a_per_g  fg3_pct  fg2_per_g  fg2a_per_g  fg2_pct  \
# 0 0.393000   1.400000    3.600000 0.381000   0.600000    1.400000 0.426000
# 1 0.571000   0.000000    0.000000 0.000000   4.700000    8.200000 0.572000
# 2 0.345000   0.200000    1.000000 0.190000   1.000000    2.500000 0.406000
# 3 0.308000   0.200000    1.000000 0.231000   1.000000    3.000000 0.333000
# 4 0.609000   0.000000    0.100000 0.000000   0.700000    1.100000 0.636000
#
# ...

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# |**Feature Name**|**Description**|
# |:---|:---|
# |player|Player Name|
# |pos|Player's Position|
# |age|Player's Age|
# |team_id|Player's Team|
# |g|Games Played|
# |gs|Games Started|
# |mp_per_g|Minutes Played Per Game|
# |fg_per_g|Total Field Goals Made Per Game|
# |fga_per_g|Total Field Goal Attempts Per Game|
# |fg_pct|Field Goal Percentage|
# |fg3_per_g|3-Point Field Goals Made Per Game|
# |fg3_a_per_g|3-Point Field Goal Attempts Per Game|
# |fg3_pct|3-Point Field Goal Make Percentage|
# |fg2_per_g|2-Point Field Goals Made Per Game|
# |fg2a_per_g|2-Point Field Goal Attempts Per Game|
# |fg2_pct|2-Point Field Goal Make Percentage|
# |efg_pct|Effective Field Goal Percentage|
# |ft_per_g|Free Throws Made Per Game|
# |fta_per_g|Free Throw Attempts Per Game|
# |ft_pct|Free Throw Make Percentage|
# |orb_per_g|Offensive Rebounds Per Game|
# |drb_per_g|Defensive Rebounds Per Game|
# |trb_per_g|Total Rebounds Per Game|
# |ast_per_g|Assists Per Game|
# |stl_per_g|Steals Per Game|
# |blk_per_g|Blocks Per Game|
# |tov_per_g|Turnovers Per Game|
# |pf_per_g|Personal Fouls Per Game|
# |pts_per_g|Points Per Game|
# |season|Season (Calendar Year in Which season ended)|
# |mp|Total Minutes Played|
# |per|Player Efficiency Rating (A measure of per-minute production standardized such that the league average is 15)|
# |ts_pct|True Shooting Percentage (A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws)|
# |fg3a_per_fga_pct|3-Point Attempt Rate|
# |fta_per_fga_pct|Free Throw Attempt Rate|
# |orb_pct|Offensive Rebound Percentage|
# |drb_pct|Defensive Rebound Percentage|
# |trb_pct|Total Rebound Percentage|
# |ast_pct|Assist Percentage (An estimate of the percentage of teammate field goals a player assisted while he was on the floor)|
# |stl_pct|Steal Percentage (An estimate of the percentage of opponent possessions that end with a steal by the player while he was on the floor)|
# |blk_pct|Block Percentage (An estimate of the percentage of opponent two-point field goal attempts blocked by the player while he was on the floor)|
# |Turnover Percentage|An estimate of turnovers committed per 100 plays|
# |usg_pct|Usage Percentage (An estimate of the percentage of team plays used by a player while he was on the floor)|
# |ows|Offensive Win Shares (An estimate of the number of wins contributed by a player due to his offense)|
# |dws|Defensive Win Shares (An estimate of the number of wins contributed by a player due to his defense)|
# |ws|Win Shares (An estimate of the number of wins contributed by a playe)|
# |ws_per_48|Win Shares Per 48 Minutes (An estimate of the number of wins contributed by a player per 48 minutes (league average is approximately .10)|
# |obpm|Offensive Box Plus/Minus (A box score estimate of the offensive points per 100 possessions a player contributed above a league-average player, translated to an average team)|
# |dbpm|Defensive Box Plus/Minus (Defensive Box Plus/Minus</b><br>A box score estimate of the defensive points per 100 possessions a player contributed above a league-average player, translated to an average team)|
# |bpm|Box Plus/Minus (A box score estimate of the points per 100 possessions a player contributed above a league-average player, translated to an average team)|
# |vorp|Value Over Replacement Player (A box score estimate of the points per 100 TEAM possessions that a player contributed above a replacement-level (-2.0) player, translated to an average team and prorated to an 82-game season. Multiply by 2.70 to convert to wins over replacement)|
# |salary|Player's Salary|
# |team_PTS|Points Scored Per Game by the player's team|
# |team_FGM|Field Goals Made Per Game by the player's team|
# |team_FGA|Field Goals Attempted Per Game by the player's team|
# |team_3PM|3-Point Field Goals Made Per Game by the player's team|
# |team_3PA|3-Point Field Goals Attempted Per Game by the player's team|
# |team_FTM|Free Throws Made Per Game by the player's team|
# |team_FTA|Free Throws Attempted Per Game by the player's team|
# |team_REB|Rebounds Per Game by the player's team|
# |team_AST|Assists Per Game by the player's team|

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
df.shape
# Out:
# (1651, 63)

# %% [markdown]
# The dataset contains 1,835 rows and 54 features.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# There are 0 null values in the dataset.

# %%
df.dtypes
# Out:
# player       object
# pos          object
# age           int64
# team_id      object
# g             int64
#              ...
# team_3PA    float64
# team_FTM    float64
# team_FTA    float64
# team_REB    float64
# team_AST    float64
# Length: 63, dtype: object

# %% [markdown]
# All of the features are the correct data type

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
df['point_share'] = df['pts_per_g'] / df['team_PTS']

# %% [markdown]
# Creating `point_share` a custom value for percentage of a team's points per game score by the given player.

# %%
df['reb_share'] = df['trb_per_g'] / df['team_REB']

# %% [markdown]
# Creating `reb_share` a custom value for percentage of a team's rebounds per game score by the given player.

# %%
df['ast_share'] = df['ast_per_g'] / df['team_AST']

# %% [markdown]
# Creating `ast_share` a custom value for percentage of a team's assits per game score by the given player.

# %%
df['fga_share'] = df['fga_per_g'] / df['team_FGA']

# %% [markdown]
# Creating `fga_share` to show the number of shots a player takes per game as a percentage of the number of team shots per game.

# %%
df['fg3a_share'] = df['fg3a_per_g'] / df['team_3PA']

# %% [markdown]
# Creating `fg3a_hare` to show percentage of a team's 3 point shot attempts come from the given player

# %%
df['fta_share'] = df['fta_per_g'] / df['team_FTA']

# %% [markdown]
# Creating `fta_share` to show percentage of a team's Free Throw Attempts that come from a given player.

# %%
df['age_score'] = (df['age'] ** 2) * df['pts_per_g']

# %% [markdown]
# Creating a new feature called `age_score` which takes a player's squared age and multiplies it by their points per game. This is to take into account a player's age and scoring ability while giving more weight to their age

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
df.describe()
# Out:
#               age           g          gs    mp_per_g    fg_per_g   fga_per_g  \
# count 1651.000000 1651.000000 1651.000000 1651.000000 1651.000000 1651.000000
# mean    26.215627   44.358571   21.173834   19.215627    3.054997    6.765112
# std      4.186359   27.205299   27.282907    9.262955    2.159835    4.513705
# min     19.000000    1.000000    0.000000    0.700000    0.000000    0.000000
# 25%     23.000000   19.000000    0.000000   12.150000    1.500000    3.400000
# 50%     26.000000   47.000000    6.000000   18.800000    2.600000    5.700000
# 75%     29.000000   71.000000   37.500000   26.900000    4.200000    9.300000
# max     42.000000   82.000000   82.000000   37.800000   10.800000   24.500000
#
#            fg_pct   fg3_per_g  fg3a_per_g     fg3_pct   fg2_per_g  fg2a_per_g  \
# count 1651.000000 1651.000000 1651.000000 1651.000000 1651.000000 1651.000000
# mean     0.437336    0.808601    2.310902    0.282319    2.247123    4.455724
# ...

# %% [markdown]
# ### Distribution of Target Variable

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
plt.figure(figsize = (15, 6))
plt.hist(df['salary'], bins = 20)

plt.xlabel('Salary - USD', size = 14)
plt.ylabel('Frequency', size = 14)
plt.title('Distribution of NBA Player Salaries 2017 - 2019', size = 20)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** Salaries in the NBA are very unbalanced and the distribution of the salaries in our data set are heavily right-skewed. This is because of the overarching policy guiding how NBA contracts are signed and the NBA's salary cap.
# The salary cap limits what each team is allowed to spend on the payroll for it's 12 active players. Most teams have at least one player signed to a “Max” Contract that can be 25-30% of the salary cap depending on certain criteria that the player meets. A few select players are also eligible for the “SuperMax” Contract which allows them to paid 35% of the salary cap. Because such a high percentage of each team's salary cap can be concentrated on just a few players, most players sign contracts fot a salary that is just a fraction of what NBA superstars earn. While the average salary is \$6,263,335.33, the median salary is \\$3M showing how much the weight the top earners' contracts carry.

# %%
plt.figure(figsize = (15, 6))
plt.hist(np.log(df['salary']), bins = 20)

plt.xlabel('Salary - USD')
plt.ylabel('Frequency')
plt.title('Distribution of Natural Log of NBA Player Salaries 2017 - 2019', size = 16)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** The log distribution of NBA salary is not normally distributed and does not offer any use to us when we begin training our models.

# %% [markdown]
# ### Correlation Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
# creating dataframe of correlations to salary 

corr_df = df.corr().drop(index = ['salary', 'season'])[['salary']]

# %%
# Function to turn feature names into human-readable code
# For graph ticks
def make_tick(feature):
    return feature.replace('_', ' ').title()

# %%
plt.figure(figsize = (6, 16))
sns.heatmap(corr_df.dropna().sort_values(by = 'salary', ascending = False), cmap = 'coolwarm', annot = True)

plt.xlabel('Correlation to Salary', size = 14)
plt.ylabel('Statistic', size = 16)
plt.yticks(np.arange(64), 
           [make_tick(stat) for stat in corr_df.dropna().sort_values(by = 'salary', ascending = False).index])

plt.title('Statistic Correlation to NBA Salary');

# %% [markdown]
# **Interpretation:** Our created `age_score` statistic most highly correlated to Salary is our created Age_Score feature. Most of the statistics most highly correlated to Salary are related to scoring - this shows what the teams value most in players they are looking to sign. It is surprising to see that only 4 of the top 25 statistics in correlation to salary are advanced statistics (`ws`, `ows`, `dws`, `vorp`). We expected that `ws` and `vorp` would be much higher.
#
# Team stats all have low correlation to Salary. This makes sense because the same team will sign players to a wide range of contracts at any given time.
#
# The only statistic with negative correlation to Salary is `fg3a_per_fga_pct` (3-Point Attempt Rate). This suggests that players that are heavily specialized in shooting 3 Point Attempts and only 3-Point attempts are not valued very highly.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['pts_per_g'], df['salary'])

plt.xlabel('Points per Game', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('Points per Game vs Salary', size = 20)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** Points per game is the feature with the highest correlation to Salary included in our original data set. We can see a weak linear relationship between `pts_per_g` and Salary but there are a lot of points that are not lined up. So while there is a general trend that a player will have a higher salary if they score more points per game, that is not a clear rule.
#
# Also note that there can be many outliers on the lower end of `pts_per_g` attributed to factors beyond performance. The most significant outlier is at 2 Points per Game with a Salary just under \\$30M. This Gordon Hayward in the 2018 season, who broke his ankle 5 minutes into the first game after scoring 2 points, and missed the remainder of the season. This outlier is one we will see on several plots moving forward.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['point_share'], df['pts_per_g'])

plt.xlabel('Point Share', size = 16)
plt.ylabel('Points Per Game', size = 18)
plt.title('Point Share vs Points Per Game', size = 20);

# %% [markdown]
# **Interpretation:** Our created `point_share` feature has a very strong linear relationship with `pts_per_g`. This is because each team scores a fairly similar number of points per game as a team, leading to each player's point share being very close to their actual points scored per game.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['age_score'], df['salary'])

plt.xlabel('Age * Points Per Game', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('Age Score vs Salary', size = 20)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretation:** Our created `age_score` feature is the feature most highly correlated to Salary in our entire dataset. This is because teams have a high value for points scored but age, which is weighted more heavily in `age_score`, plays a large factor as well when determining a player's salary, due to NBA contract policies, which will be discussed in more depth later in the notebook.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['usg_pct'], df['salary'])

plt.xlabel('Usage Rate', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('Usage Rate vs NBA Salary', size = 20)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** While we initially expected there to be a strong linear relationship between `usg_rate` and Salary, because we assumed players who were a more central focus of the team's offense on a per-play basis would be paid more, we were suprised to find that many of the players with the highest usage rates were on the lower end of the Salary spectrum. We have noticed that the players who earn the highest salaries generally have a `usg_rate` between 20% and 32%.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['ws'], df['salary'])

plt.xlabel('Win Shares', size = 16)
plt.ylabel('Salary', size =18)
plt.title('Win Shares vs Salary', size = 20)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** As previosly mentioned, Win-Shares are one of the advanced statistics that would correlate highly with Salary. However it appears that there is quite a large distribution of Win-Shares and players can both contribute heavily to wins while not being highly paid, and be highly paid without contributing to many wins. This could also be because there are many players who are highly paid but on bad teams - so they will not be able to contribute as many wins to lesser paid players on good teams.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['vorp'], df['salary'])

plt.xlabel('Value Over Replacement Player', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('Value Over Replacement Player vs Salary', size = 20)

ax = plt.gca()
ax.ticklabel_format(style='plain')
plt.draw();

# %% [markdown]
# **Interpretation:** Similar to Win-Shares, we expected Value Over Replacement Player to have a much stronger correlation to Salary before we began examining the data. However because of the nature of the statistic, most players will hover around 0 `vorp` regardless of how much they are paid.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['team_PTS'], df['salary'])

plt.xlabel('Team Points per Game', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('Salary by Team Points per Game', size = 20)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretation** Not much of a trend to found overall as each dot on the vertical line represents a player on the team. However it is interesting to compare the peaks of each vertical line. The highest dot on each vertical line represents the highest paid player on each team. When comparing just the peaks, we can observe an upward slope. So, because the NBA prioritizes scoring, it would stand to reason that the highest paid player on teams that score the most points would earn more than players on their lower scoring counterparts.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['mp_per_g'], df['salary'])

plt.xlabel('Minutes per Game', size =16)
plt.ylabel('Salary', size =18)
plt.title('Minutes per Game vs Salary', size = 20)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretation:** While `mp_per_g` does not have an especially linear relationship with Salary, we some semblence of a slope along the tops of each level of `mp_per_g` this suggests that many players play a lot of minutes per game, there is a sort of limit to their salary based on `mp_per_g`.
#
# Gordon Hayward in the 2018 Season is an outlier once again at 5 `mp_per_g` due to his previously mentioned season-ending injury.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['fg3a_per_fga_pct'], df['salary'])

plt.xlabel('3pt Attempt Rate', size = 16)
plt.ylabel('Salary', size = 18)
plt.title('3pt Attempt Rate vs Salary', size = 20)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretation:** `fg3a_per_fga_pct` is the feature in our data set with the lowest correlation to Salary and is the only feature with a negative correlation to Salary. Here we can see there is no linear relationship between `fg3a_per_fga_pct` and our target. We can also see that the lowest end of `fg3a_per_fga_pct` has a wide range of Salaries while players at the upper end of `fg3a_per_fga_pct` have salaries that are mostly below the league average.

# %%
df.sort_values(by = 'fg3a_per_fga_pct', ascending = False).head(10)
# Out:
#                 player pos  age team_id   g  gs  mp_per_g  fg_per_g  \
# 807   Nicolas Brussino  SF   24     ATL   4   0  2.500000  0.000000
# 583      Anthony Brown  SF   25     MIN   1   0  4.000000  1.000000
# 837       Julyan Stone  SG   29     CHO  23   0  7.600000  0.300000
# 263       Axel Toupane  SF   24     MIL   2   0  3.000000  0.000000
# 920      Chris Boucher  PF   25     GSW   1   0  1.000000  0.000000
# 769       Jarell Eddie  SF   26     CHI   1   0  3.000000  0.000000
# 753        Nigel Hayes  SF   23     TOR   2   0  3.000000  1.000000
# 751      Bruno Caboclo  SF   22     TOR   2   0  3.500000  0.000000
# 1002      Reggie Hearn  SG   26     DET   3   0  2.300000  0.300000
# 1030    David Stockton  PG   26     UTA   3   0  3.000000  0.700000
#
#       fga_per_g   fg_pct  fg3_per_g  fg3a_per_g  fg3_pct  fg2_per_g  \
# 807    0.500000 0.000000   0.000000    0.500000 0.000000   0.000000
# 583    1.000000 1.000000   1.000000    1.000000 1.000000   0.000000
# ...

# %% [markdown]
# **Interpretation:** These are the players that are top 10 in 3-Point Attempt Rate. All of these players are low production players who have very few games played, games started, and points per game. This suggests that players who take a majority of their shot attempts from 3-Point range, do so in very limited time on the court, and are not highly valued.

# %%
top_25 = df.sort_values(by = 'salary', ascending = False).head(25)

top_25_corr = top_25.corr()[['salary']].sort_values(by = 'salary', ascending = False).drop(index = 'salary').dropna()

# %%
top_25_corr.shape
# Out:
# (64, 1)

# %%
plt.figure(figsize = (6, 16))

sns.heatmap(top_25_corr, cmap = 'coolwarm', annot = True)

plt.xlabel('Correlation to Salary', size = 14)
plt.ylabel('Statistic', size = 16)

plt.yticks(np.arange(64),
           [make_tick(stat) for stat in top_25_corr.index])

plt.title('Statistic Correlation to the top 25 NBA Salaries (2017 - 2019)', size = 14);

# %% [markdown]
# **Interpretation** Because these are only among the top 20 salaries, the higher correlations do not reflect the trends of the league as a whole but only among those at the top of the pay scale. Therefore, statistics with the higher correlation here serve only as seperators among the league's top earners, while lower correlations are statistics where they are relatively similar.

# %% [markdown]
# ### Season Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
df.groupby('season').mean()
# Out:
#              age         g        gs  mp_per_g  fg_per_g  fga_per_g   fg_pct  \
# season
# 2017   26.399209 48.363636 23.126482 19.738735  3.090316   6.851581 0.438445
# 2018   26.156140 42.921053 20.391228 18.758421  2.967368   6.569123 0.438867
# 2019   26.113043 42.259130 20.231304 19.208522  3.110783   6.883304 0.434843
#
#         fg3_per_g  fg3a_per_g  fg3_pct  fg2_per_g  fg2a_per_g  fg2_pct  \
# season
# 2017     0.766601    2.174704 0.278227   2.326285    4.675692 0.480065
# 2018     0.781930    2.220000 0.275958   2.185614    4.351579 0.479961
# 2019     0.872000    2.520870 0.292224   2.238435    4.365391 0.481136
#
#         efg_pct  ft_per_g  fta_per_g   ft_pct  orb_per_g  drb_per_g  \
# season
# 2017   0.491332  1.404545   1.835968 0.714198   0.840514   2.719960
# 2018   0.494858  1.249298   1.635088 0.675204   0.766316   2.574912
# 2019   0.496835  1.333913   1.761217 0.691821   0.838435   2.780348
#
# ...

# %% [markdown]
# **Interpretation** Team 3 point attempts have increased every year from 27.2 in 2017 to 32.4 in 2019. Total shot attempts have increased from  in 2017 to 89.2 in 2019.
# From 2017 - 2019, `fg3a_per_fga_pct` increased by 6.1%. Part of this is due to players shooting more 3 pointers in 2018-19 than any previous year in NBA history.

# %%
plt.bar(df.groupby('season').mean().index, df.groupby('season')['salary'].mean())

plt.xticks(df.groupby('season').mean().index)
plt.xlabel('Season')
plt.ylabel('Average Salary')
plt.title('Average NBA Salary by Season (2017 - 2019)');

# %% [markdown]
# **Interpretation:** The NBA salary cap increased from \\$94M in 2016-17 tp to \\$99M in 2017-18 to \\$101M in 2018-19 so players signing contracts in subsequent years will have higher salaries on average than similar players that signed in the years before. This has led to the average NBA salary increasing by \\$912,256.39 between the 2017 season and the 2019 season.

# %%
plt.figure(figsize = (8, 6))

sns.boxplot(df['season'], df['salary'])

plt.xlabel('Season', size = 12)
plt.ylabel('Salary', size = 12)
plt.title('Distribution of NBA Salary by Season', size = 16)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretaion**
# While the salary increase raised the average NBA salary, we can also see that much of this group is focused amoing the top NBA earners. So while the average NBA salary increased by \\$912,256.39, the NBA's highest salary rose by \\$6,493,704.00. This is a result of Stephen Curry becoming the first player to sign the previously mentioned SuperMax Extension.

# %%
s_17 = df[df['season'] == 2017]
s_18 = df[df['season'] == 2018]
s_19 = df[df['season'] == 2019]

# %%
corr_diff = (s_19.corr()[['salary']] - s_17.corr()[['salary']]).dropna().sort_values(by = 'salary', ascending = False)

# %%
corr_diff.head(15)
# Out:
#                   salary
# tov_pct         0.128212
# fta_per_fga_pct 0.087109
# age             0.080730
# stl_per_g       0.049298
# fg2_pct         0.044433
# dbpm            0.043946
# ast_share       0.041193
# blk_pct         0.041193
# ast_per_g       0.038637
# fg3a_share      0.038005
# stl_pct         0.036361
# ft_pct          0.035989
# blk_per_g       0.034656
# orb_per_g       0.030200
# fg3a_per_g      0.030052

# %% [markdown]
# **Interpretation** These are the differrences in the correlation to salary for statistics from the 2017 season to the 2019 season. Positive numbers are more highly correlated in the 2019 Season while negative numbers are less correlated. The magnitude of the number represents the difference in correlation.

# %% [markdown]
# ### Age Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['age'], df['pts_per_g'])

plt.xlabel('Age', size = 16)
plt.ylabel('Points per Game', size = 18)
plt.title('Age vs Points Per Game', size = 20);

# %% [markdown]
# **Interpretation:** Players of each age group score a wide range of points per game and scoring prowess is not limited any any period in a player's career as there are high `pts_per_g` stats by players as old as 34.

# %%
plt.figure(figsize = (8, 6))

sns.boxplot(df['age'])

plt.xlabel('Age', size = 16)

plt.title('Distribution of Age Among NBA Players', size = 18);

# %% [markdown]
# **Interpretation:** The average age of an NBA player is 26 years old and the ages range from 19 to 42 years old.

# %%
plt.figure(figsize =(12, 6))

sns.boxplot(df['age'], df['salary'])

plt.xlabel('Season', size = 12)
plt.ylabel('Salary', size = 12)
plt.title('Distribution of NBA Salary by Age', size = 16)

plt.ticklabel_format(style='plain', axis='y',useOffset=False);

# %% [markdown]
# **Interpretation:** Ages 19 - 24 are the years with the lowest average salary and very few outliers. These are the years when players on fixed rookie contracts based on draft position with no ability to negotiate. Rookie contracts are 2 years with team options for the 3rd and 4th years (meaning the team can extend for an additional year if they so choose), and players typically enter the league between the ages of 19 - 22. Though many of the higher skill players will enter at age 19 because they are only required to be 1 year removed from high school, per NBA policy.

# %%
ages = []
for age in df['age'].unique():
    ages.append(f'age_{age}')

# %%
age_corr = pd.get_dummies(df, 
                          columns = ['age']).corr()[['salary']]

age_corr = age_corr.loc[ages, :].sort_values(by = 'salary', ascending = False)

# %%
plt.figure(figsize = (6, 10))
sns.heatmap(age_corr, cmap = 'coolwarm', annot = True)

plt.xlabel('Correlation to Salary', size = 15)
plt.ylabel('Age', size = 18)
plt.yticks(np.arange(24), [age[-2::] for age in age_corr.index])

plt.title('Correlation of Age to Salary', size = 18);

# %% [markdown]
# **Interpretaion** The most highly correlated years are 26-32 which are widely considered to be the modern NBA player's prime and are when most players would be playing under their second and/or third post-rookie contracts - which are the highest that most players (especially stars that are in the upper echelon of salary) will recieve.

# %% [markdown]
# ### Team and Position Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
team_corr = pd.get_dummies(df, 
                           columns = ['team_id']).corr()[['salary']].tail(30).sort_values(by = 'salary', ascending = False)

# %%
plt.figure(figsize = (6, 9))
sns.heatmap(team_corr,
            cmap = 'coolwarm',
            annot = True)

plt.xlabel('Correlation to Salary')
plt.ylabel('Team')

plt.yticks(np.arange(30), 
           labels =  [team[-3::] for team in team_corr.index])

plt.title('Correlation to Player Salary by Team');

# %% [markdown]
# **Interpretation:** Team is very weakly correlated to Salary because each team pays a wide range of salaries. From this we can tell that it will not be useful to dummify the `team_id` column.

# %%
plt.figure(figsize = (8, 6))

sns.barplot(x = df.groupby('pos').count().sort_values(by = 'salary', ascending = False).index, 
            y = df.groupby('pos')['player'].count().sort_values(ascending = False))

plt.xlabel('Position', size = 16)

plt.title('Count of NBA Players by Position 2017-2019', size = 20)
# Out:
# Text(0.5, 1.0, 'Count of NBA Players by Position 2017-2019')

# %% [markdown]
# **Interpretation:** Here we can see the number of players at each position. The two positions with the least amount of representation are Small Forward, which is generally considered to be the most versatile position and is highly valued, and Center - which is almost always the tallest members of the team and thus has the highest natural barrier to entry

# %%
plt.figure(figsize = (8, 6))

sns.barplot(x = df.groupby('pos').mean().sort_values(by = 'salary', ascending = False).index, 
            y = df.groupby('pos').mean().sort_values(by = 'salary', ascending = False)['salary'])

plt.xlabel('Position')
plt.ylabel('Average Salary - USD')
plt.title('Average Salary by Position', size = 16);

# %% [markdown]
# **Interpretation:** Centers have the highest average Salary in part because there are so few of them and it is the position with the highest barrier to entry as NBA centers are the tallest members of the team. Shooting Guard has the lowest average Salary, possibly due to the fact that Shooting Guard is the most popular position thus the Shooting Guard market is saturated with talent - lowering the demand.

# %%
pos_corr = pd.get_dummies(df, 
                          columns = ['pos']).corr()[['salary']].tail(5).sort_values(by = 'salary', ascending = False)

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(pos_corr,
            cmap = 'coolwarm',
            annot = True)

plt.xlabel('Correlation to Salary')
plt.ylabel('Position')

plt.yticks(np.arange(5), 
           labels =  [pos[-2::].replace('_', '') for pos in pos_corr.index])

plt.title('Correlation to Player Salary by Position');

# %% [markdown]
# **Interpretation:** There is some useful correlation between `pos` and Salary and so it will be useful to dummify the position column.

# %%
df = pd.get_dummies(df, columns = ['pos'])

# %% [markdown]
# ## Clustering

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
#Create clusters based on age_score, age, and mp_per_g
Z = df.loc[:, ['age_score', 'age', 'mp_per_g']]

# We must scale the data before clustering
ss = StandardScaler()
Z_ss = ss.fit_transform(Z)

# Creating 12 clusters to segment each cluster into distinct groups
km = KMeans(n_clusters = 12, random_state=RANDOM_STATE)
km.fit(Z_ss)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=12, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=999, tol=0.0001, verbose=0)

# %%
# Create 'cluster' column for our dataframe 
# Displays the cluster each player belongs to

df['cluster'] = km.labels_

# %%
silhouette_score(Z_ss, km.labels_)
# Out:
# 0.3097549794365516

# %%
check_cluster = ['age', 'g', 'gs', 'mp_per_g', 'pts_per_g', 'salary']

# %%
round(df.groupby('cluster').mean().sort_values(by = 'salary', ascending = False)[check_cluster], 2)
# Out:
#               age         g        gs  mp_per_g  pts_per_g          salary
# cluster
# 2       29.830000 64.450000 63.670000 33.910000  22.400000 23533836.090000
# 8       26.520000 60.660000 55.390000 32.070000  18.340000 14802999.570000
# 1       30.350000 56.130000 38.200000 26.550000  10.770000 11062603.300000
# 9       36.090000 54.640000 17.890000 22.220000   9.460000  9763421.400000
# 7       25.980000 56.750000 29.300000 25.280000   9.930000  7234204.700000
# 10      22.330000 64.350000 54.020000 30.520000  15.040000  6411301.870000
# 6       28.690000 43.240000  9.160000 17.100000   6.040000  6307986.410000
# 5       33.900000 35.170000  5.180000 12.680000   4.010000  5353815.780000
# 11      28.200000 18.170000  1.030000  7.170000   2.300000  3447058.550000
# 3       21.560000 53.690000 18.120000 19.990000   7.410000  2341780.590000
# 4       24.150000 38.980000  4.240000 14.450000   4.980000  2238899.180000
# ...

# %% [markdown]
# **Interpretation:** Here we can see how each cluster has formed a distinct group of players. For example, Cluster 2 appears to be a high scoring player in the prime of their career who plays a high number of minutes while starting every game and thus has a high paying contract.
#
# On the opposite end of things we have Cluster 0. The average player in Cluster 0 appears to be a young player who gets very little playing and does not contribute much in the way of scoring. So it makes sense that they would have the lowest contracts, well below league average.

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(df['age'], df['pts_per_g'], hue = df['cluster'], palette = 'coolwarm')

plt.xlabel('Age', size = 16)
plt.ylabel('Points Per Game', size = 18)
plt.title('Age vs Points Per Game', size = 20)

plt.legend();

# %% [markdown]
# **Interpretation:** Here we ca see which players in different age groups belong to which clusters. Clusters seem to typically encompass 4-5 year age ranges that are within about 5 `pts_per_g` of each other. It is encouraging to see 3 diffesrent clusters in the 19-23 age range.

# %%
plt.figure(figsize = (8, 6))

sns.boxplot(df['cluster'], df['salary'])

plt.xlabel('Cluster', size = 16)
plt.ylabel('Salary', size = 18)

plt.ticklabel_format(style='plain', axis='y',useOffset=False)

plt.title('Salary Distribution by Cluster', size = 20);

# %% [markdown]
# **Interpretation:** Here we can see the Salary distribution of each cluster. Each cluster would preferably have a very small box plot but that is not always the case. However we do see clear trends in terms of the hierarchy of clusters by Salary. WE can clearly see Cluster 2 has the highest average salary and the highest salaries overall, but the two outliers on the lower end are cause for concern. We can also see that cluster 0 has the lowest Salaries, in terms of average, 75th percentile and outliers.

# %%
plt.figure(figsize = (10, 6))

sns.boxplot(df['cluster'], df['age'], hue = df['cluster'], palette = 'coolwarm')

plt.xlabel('Cluster', size = 16)
plt.ylabel('Age', size = 18)
plt.title('Distribution of Age by Cluster', size = 20);

# %% [markdown]
# **Interpretation:** Here we can see the age distribution of each cluster. We can see that some clusters are focused on younger players, some on players in their primes, and on the oldest players. It is important to not that these box plots have very few outliers so our clusters are all very tight when looking specifically at age.

# %%
clusters = ['cluster_0', 'cluster_1', 'cluster_2', 'cluster_3', 'cluster_4',
            'cluster_5', 'cluster_6', 'cluster_7', 'cluster_8', 'cluster_9',
            'cluster_10', 'cluster_11']

cluster_corr = pd.get_dummies(df, columns = ['cluster']).corr()[['salary']]

cluster_corr = cluster_corr.loc[clusters, :].sort_values(by = 'salary', ascending = False)

# %%
plt.figure(figsize = (6, 7))

sns.heatmap(cluster_corr, cmap = 'coolwarm', annot = True)

plt.xlabel('Correlation to Salary', size = 14)
plt.ylabel('KMeans Cluster', size = 15)
plt.yticks(np.arange(12), [make_tick(cluster) for cluster in cluster_corr.index])

plt.title('Cluster Correlation to Salary', size = 16);

# %% [markdown]
# **Interpretation:** Similar to the table above, we can see the correlation that each cluster has with Salary. The clusters with the highest average Salary are at the top and vice versa. The correlations would most likely be stringer on both the positive and negative ends if each cluster was free of outliers in Salary.

# %% [markdown]
# ## Model Preparation

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# ### Dummifying Columns

# %%
df = pd.get_dummies(df, columns = ['cluster'])

df = pd.get_dummies(df, columns = ['season'])

# %% [markdown]
# ### RMSE Functions

# %%
# Function that returns RMSE given a model, X, and y
def get_rmse(model, X, y):
    
    preds = model.predict(X)
    rmse = np.sqrt(mean_squared_error(y, preds))
    return round(rmse, 2)

# Function for cross_val_score that return RMSE given true y and predicted y
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ### Feature Sets

# %%
low_corr_cols = ['fg_pct', 'fg3_pct', 'fg2_pct', 'efg_pct', 'ts_pct', 'fg3a_per_fga_pct',
       'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct', 'stl_pct',
       'blk_pct', 'tov_pct', 'dbpm', 'team_PTS', 'team_FGM', 'team_FGA',
       'team_3PM', 'team_3PA', 'team_FTM', 'team_FTA', 'team_REB', 'team_AST', 'salary', 'player', 'pos', 'team_id']

high_corr_cols = ['gs', 'mp_per_g', 'fg_per_g', 'fga_per_g', 'fg2_per_g', 'fg2a_per_g',
       'ft_per_g', 'fta_per_g', 'drb_per_g', 'trb_per_g', 'ast_per_g',
       'tov_per_g', 'pts_per_g', 'mp', 'ows', 'dws', 'ws', 'vorp',
       'point_share', 'reb_share', 'fga_share', 'fta_share', 'ast_share', 'age_score']

highest_corr_cols = ['fg_per_g', 'fga_per_g', 'pts_per_g', 'point_share', 'fga_share', 'age_score']

basic_cols = ['g', 'gs', 'mp_per_g', 'fg_per_g',
       'fga_per_g', 'fg_pct', 'fg3_per_g', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'orb_per_g', 'drb_per_g', 'trb_per_g',
       'ast_per_g', 'stl_per_g', 'blk_per_g', 'tov_per_g', 'pf_per_g',
       'pts_per_g', 'point_share', 'reb_share',
       'ast_share', 'fga_share', 'fg3a_share', 'fta_share']

basic_pos = ['g', 'gs', 'mp_per_g', 'fg_per_g',
       'fga_per_g', 'fg_pct', 'fg3_per_g', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'orb_per_g', 'drb_per_g', 'trb_per_g',
       'ast_per_g', 'stl_per_g', 'blk_per_g', 'tov_per_g', 'pf_per_g',
       'pts_per_g', 'pos_C', 'pos_PF', 'pos_PG', 'pos_SF',
       'pos_SG',]

basic_pos_age = ['g', 'gs', 'mp_per_g', 'fg_per_g',
       'fga_per_g', 'fg_pct', 'fg3_per_g', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'orb_per_g', 'drb_per_g', 'trb_per_g',
       'ast_per_g', 'stl_per_g', 'blk_per_g', 'tov_per_g', 'pf_per_g',
       'pts_per_g', 'point_share', 'reb_share','fg3a_share', 'fta_share',
       'ast_share', 'fga_share', 'pos_C', 'pos_PF', 'pos_PG', 'pos_SF',
       'pos_SG', 'age_score']


basic_pos_team = [ 'g', 'gs', 'mp_per_g', 'fg_per_g',
       'fga_per_g', 'fg_pct', 'fg3_per_g', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'orb_per_g', 'drb_per_g', 'trb_per_g',
       'ast_per_g', 'stl_per_g', 'blk_per_g', 'tov_per_g', 'pf_per_g',
       'pts_per_g', 'point_share', 'reb_share','fg3a_share', 'fta_share',
       'ast_share', 'fga_share', 'pos_C', 'pos_PF', 'pos_PG', 'pos_SF',
       'pos_SG', 'team_id_ATL', 'team_id_BOS', 'team_id_BRK', 'team_id_CHI',
       'team_id_CHO', 'team_id_CLE', 'team_id_DAL', 'team_id_DEN',
       'team_id_DET', 'team_id_GSW', 'team_id_HOU', 'team_id_IND',
       'team_id_LAC', 'team_id_LAL', 'team_id_MEM', 'team_id_MIA',
       'team_id_MIL', 'team_id_MIN', 'team_id_NOP', 'team_id_NYK',
       'team_id_OKC', 'team_id_ORL', 'team_id_PHI', 'team_id_PHO',
       'team_id_POR', 'team_id_SAC', 'team_id_SAS', 'team_id_TOR',
       'team_id_UTA', 'team_id_WAS']


advanced_cols = ['mp', 'per', 'ts_pct', 'fg3a_per_fga_pct',
       'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct', 'ast_pct',
       'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'ws-dum', 'ows', 'dws',
       'ws', 'ws_per_48', 'bpm-dum', 'obpm', 'dbpm', 'bpm', 'vorp', 'point_share', 'reb_share',
       'ast_share', 'fga_share', 'fg3a_share', 'fta_share']

advanced_pos = ['mp', 'per', 'ts_pct', 'fg3a_per_fga_pct',
       'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct', 'ast_pct',
       'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'ws-dum', 'ows', 'dws',
       'ws', 'ws_per_48', 'bpm-dum', 'obpm', 'dbpm', 'bpm', 'vorp', 'point_share', 'reb_share',
       'ast_share', 'fga_share', 'fg3a_share', 'fta_share', 'pos_C', 'pos_PF', 'pos_PG', 'pos_SF',
       'pos_SG', 'age_score']

created_cols = ['point_share', 'reb_share',
       'ast_share', 'fga_share', 'fg3a_share', 'fta_share', 'age_score']

team = ['team_PTS', 'team_FGM', 'team_FGA',
       'team_3PM', 'team_3PA', 'team_FTM', 'team_FTA', 'team_REB', 'team_AST','team_id_ATL', 'team_id_BOS', 'team_id_BRK', 'team_id_CHI',
       'team_id_CHO', 'team_id_CLE', 'team_id_DAL', 'team_id_DEN',
       'team_id_DET', 'team_id_GSW', 'team_id_HOU', 'team_id_IND',
       'team_id_LAC', 'team_id_LAL', 'team_id_MEM', 'team_id_MIA',
       'team_id_MIL', 'team_id_MIN', 'team_id_NOP', 'team_id_NYK',
       'team_id_OKC', 'team_id_ORL', 'team_id_PHI', 'team_id_PHO',
       'team_id_POR', 'team_id_SAC', 'team_id_SAS', 'team_id_TOR',
       'team_id_UTA', 'team_id_WAS', 'player', 'salary']

team_stats = ['team_PTS', 'team_FGM', 'team_FGA',
       'team_3PM', 'team_3PA', 'team_FTM', 'team_FTA', 'team_REB', 'team_AST',]

seasons = ['season_2017', 'season_2018', 'season_2019']

pos = ['pos_C', 'pos_PF', 'pos_PG', 'pos_SF',
       'pos_SG']

clusters = ['cluster_0', 'cluster_1', 'cluster_2', 'cluster_3', 'cluster_4',
            'cluster_5', 'cluster_6', 'cluster_7', 'cluster_8', 'cluster_9',
            'cluster_10', 'cluster_11']

scoring = ['fg_per_g', 'fga_per_g', 'fg_pct', 'fg3_per_g','ts_pct', 'efg_pct', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'pts_per_g', 'point_share','fga_share', 'fg3a_share', 'fta_share', 'age_score']

passing = ['ast_per_g', 'ast_pct','tov_per_g','ast_share']

offense = ['fg_per_g', 'fga_per_g', 'fg_pct', 'fg3_per_g','ts_pct', 'efg_pct', 'fg3a_per_g', 'fg3_pct',
       'fg2_per_g', 'fg2a_per_g', 'fg2_pct', 'efg_pct', 'ft_per_g',
       'fta_per_g', 'ft_pct', 'pts_per_g', 'point_share','fga_share', 'fg3a_share', 'fta_share', 
           'ast_per_g', 'ast_pct','tov_per_g','ast_share','tov_pct', 'usg_pct', 'age_score'
          ]

defense = ['drb_per_g','stl_per_g','pf_per_g','drb_pct','dws', 'dbpm']

# %% [markdown]
# ## Modeling

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# **Note**
# All gridsearches have been adjusted to only contain best parameters for convenience when running this notebook in it's entirety

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df.drop(columns = ['salary'])
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
baseline_model = DummyRegressor(strategy = 'mean')

baseline_model.fit(X_train, y_train)
# Out:
# DummyRegressor(constant=None, quantile=None, strategy='mean')

# %%
print(f'Train Score:   {baseline_model.score(X_train, y_train)}')
print(f'Test Score:   {baseline_model.score(X_test, y_test)}')
# Out:
# Train Score:   0.0
# Test Score:   -0.004202425158959855

# %%
print(f'Train RMSE:      {get_rmse(baseline_model, X_train, y_train)}')
print(f'Test RMSE:       {get_rmse(baseline_model, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(baseline_model, X_test, y_test, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      7116919.02
# Test RMSE:       7579804.27
# Cross-Val RMSE:  7578646.19

# %% [markdown]
# **Interpretation:** On average, the baseline model's predictions are incorrect by $7,579,804.27 and none of the variance is explained by the mean. This is a very high amount of error as this is greater than the total average NBA Salry and should be an easy score for the rest of out models to beat.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters +seasons + advanced_pos]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test_pred = lr.predict(X_test)

# %%
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
print(cross_val_score(lr, X, y).mean())
# Out:
# 0.6151092802662397
# 0.6075360962879364
# 0.5878329049204785

# %%
print(f'Train RMSE:      {get_rmse(lr, X_train, y_train)}')
print(f'Test RMSE:       {get_rmse(lr, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(lr, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      4415305.36
# Test RMSE:       4738569.1
# Cross-Val RMSE:  4613371.2

# %% [markdown]
# **Interpretation:** The Linear Regression offers a significant imporvement over the Baseline but still has a high degree of error with an RMSE of \\$4,738,569.10. It is also very slightly overfit.

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + seasons + basic_pos + created_cols]
y = df['salary']

X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train_r)
X_test_sc = ss.transform(X_test_r)

# %%
# Creating a list of potential alphas:
r_alphas = np.logspace(1, 5, 200)

# Instantiating our ridge model and cross-validating over our list of ridge alphas:
ridge = RidgeCV(
          alphas = r_alphas,
          scoring= 'r2', 
          cv = 5)

# Fitting our ridge model using best ridge alpha:
ridge.fit(X_train_sc, y_train_r);

print(f'Training Score:    {ridge.score(X_train_sc, y_train_r)}')
print(f'Testing Score:     {ridge.score(X_test_sc, y_test_r)}')
print(f'Cross-Val Score:   {cross_val_score(ridge, X, y).mean()}')
# Out:
# Training Score:    0.6186382823934016
# Testing Score:     0.620062566094219
# Cross-Val Score:   0.5906026829431539

# %%
print(f'Train RMSE:      {get_rmse(ridge, X_train_sc, y_train_r)}')
print(f'Test RMSE:       {get_rmse(ridge, X_test_sc, y_test_r)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(ridge, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      4395017.13
# Test RMSE:       4662334.2
# Cross-Val RMSE:  4596538.67

# %% [markdown]
# **Interpretation:** Our Ridge model also offers a signigicant improvement over the baseline but still has a relatively high high amount of error with a test RMSE of \\$4,662,334.20. However, the difference bewteen the training and test scores are neglible which is very encouraging. The increased performance of our Ridge model suggests that some regularization of features was beneficial to making more accurate predictions. The similar cross-val-score, ensures us that this not a mistake.

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + seasons + basic_pos + created_cols]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
# Creating a list of potential alphas:
l_alphas = np.logspace(1, 3, 50)

# Instantiating our lasso model and cross-validating over our list of Lasso alphas:
lasso = LassoCV(max_iter=75_000,
                alphas = l_alphas,
                cv=5,
                random_state = RANDOM_STATE)

# Fitting our lasso model using best ridge alpha:
lasso.fit(X_train_sc, y_train);

# Scoring 
print(f'Training Score:    {lasso.score(X_train_sc, y_train)}')
print(f'Testing Score:     {lasso.score(X_test_sc, y_test)}')
print(f'Cross-Val Score:   {cross_val_score(lasso, X, y).mean()}')
# Out:
# Training Score:    0.6287129189598396
# Testing Score:     0.5962051297748752
# Cross-Val Score:   0.5901434311276272

# %%
print(f'Train RMSE:      {get_rmse(lasso, X_train_sc, y_train)}')
print(f'Test RMSE:       {get_rmse(lasso, X_test_sc, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(lasso, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      4336575.82
# Test RMSE:       4806486.83
# Cross-Val RMSE:  4599100.43

# %% [markdown]
# **Interpretation:** Our Lasso Model is similar in performance to our Linear Regression and Ridge models but is slightly more overfit with a lowering train RMSE and a worse testing score with an RMSE of \\$4,806,486.83. The Lasso regularization may have gone too far in decreasing coefficients leading to this higher variance.

# %% [markdown]
# ## K Nearest Neighbors

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + created_cols + seasons + basic_cols]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
pipe = Pipeline([
    ('ss', StandardScaler()),
    ('mm', MinMaxScaler()),
    ('knn', KNeighborsRegressor())
])

pipe_params = {
    'ss__with_mean'       : [True],
    'ss__with_std'        : [False],
    'knn__n_neighbors'    : [9],
    'knn__weights'        : ['distance'],
    'knn__metric'         : ['minkowski']
}

gs = GridSearchCV(pipe,
                  param_grid = pipe_params,
                  cv = 3)

knn = gs.fit(X_train, y_train)

# %%
knn.best_params_
# Out:
# {'knn__metric': 'minkowski',
#  'knn__n_neighbors': 9,
#  'knn__weights': 'distance',
#  'ss__with_mean': True,
#  'ss__with_std': False}

# %%
print(f'Training Score:    {knn.score(X_train, y_train)}')
print(f'Testing Score:     {knn.score(X_test, y_test)}')
print(f'Cross-Val Score:   {cross_val_score(knn, X, y).mean()}')
# Out:
# Training Score:    1.0
# Testing Score:     0.5368817737930527
# Cross-Val Score:   0.5435294737350344

# %%
print(f'Train RMSE:      {get_rmse(knn, X_train, y_train)}')
print(f'Test RMSE:       {get_rmse(knn, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(knn, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      0.0
# Test RMSE:       5147463.72
# Cross-Val RMSE:  4854770.28

# %% [markdown]
# **Interpretation:** Our KNN model is incredibly overfit, correctly predicting each target in our training set but having a test RMSE of \\$5,147,463.72, making it our worst performing model so far. This model has the lowest bias but incredibly high variance.

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + basic_pos + seasons]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
pipe = Pipeline([
    ('ss', StandardScaler()),
    ('mm', MinMaxScaler()),
    ('dt', DecisionTreeRegressor(random_state = RANDOM_STATE))
])

pipe_params = {
    'ss__with_mean'         : [True],
    'ss__with_std'          : [True],
    'dt__max_depth'         : [5],
    'dt__min_samples_split' : [2],
    'dt__min_samples_leaf'  : [1],
    'dt__max_features'      : [None],
}

dt = GridSearchCV(pipe, 
                  param_grid = pipe_params,
                  cv = 3)

dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('ss',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('mm',
#                                         MinMaxScaler(copy=True,
#                                                      feature_range=(0, 1))),
#                                        ('dt',
#                                         DecisionTreeRegressor(ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features=None,
#                                                               max_leaf_nodes=None,
# ...

# %%
print(f'Training Score:  {dt.score(X_train, y_train)}')
print(f'Testing Score:  {dt.score(X_test, y_test)}')
print(f'Cross-Val Score:  {cross_val_score(dt, X, y).mean()}')
# Out:
# Training Score:  0.6257284326655629
# Testing Score:  0.5196624383048116
# Cross-Val Score:  0.4164688207795992

# %%
print(f'Train RMSE: {get_rmse(dt, X_train, y_train)}')
print(f'Test RMSE: {get_rmse(dt, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(dt, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE: 4353970.1
# Test RMSE: 5242285.06
# Cross-Val RMSE:  5448961.56

# %% [markdown]
# **Interpretation:** While not as overfit as our KNN model, our Decision Tree model is still very overfit with a very high test RMSE of \\$5,242,285.06. This is something that may be fixed by bagging or creating a Random Forest to reduct variance.

# %% [markdown]
# ## Random Forest

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + basic_pos + seasons]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
pipe = Pipeline([
    ('ss', StandardScaler()),
    ('rf', RandomForestRegressor(random_state = RANDOM_STATE))
])

pipe_params = {
    'ss__with_mean'         : [True],
    'ss__with_std'          : [False],
    'rf__n_estimators'      : [100],
    'rf__max_depth'         : [None],
    'rf__min_samples_split' : [5],
    'rf__min_samples_leaf'  : [3],
    'rf__max_features'      : [.5],
    'rf__bootstrap'         : [True]
}

rf = GridSearchCV(pipe,
                  param_grid = pipe_params,
                  cv = 3)

rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('ss',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('rf',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
# ...

# %%
rf.best_params_
# Out:
# {'rf__bootstrap': True,
#  'rf__max_depth': None,
#  'rf__max_features': 0.5,
#  'rf__min_samples_leaf': 3,
#  'rf__min_samples_split': 5,
#  'rf__n_estimators': 100,
#  'ss__with_mean': True,
#  'ss__with_std': False}

# %%
print(f'Training Score:  {rf.score(X_train, y_train)}')
print(f'Testing Score:  {rf.score(X_test, y_test)}')
print(f'Cross-Val Score:  {cross_val_score(rf, X, y).mean()}')
# Out:
# Training Score:  0.8714638813339032
# Testing Score:  0.5872798468729297
# Cross-Val Score:  0.5670485338849159

# %%
print(f'Train RMSE: {get_rmse(rf, X_train, y_train)}')
print(f'Test RMSE: {get_rmse(rf, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(rf, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE: 2551553.13
# Test RMSE: 4859316.6
# Cross-Val RMSE:  4730021.01

# %% [markdown]
# **Interpretation:** Our Random Forest is even more overfit than our Decision Tree and has a worse testing score than several of our previous models. Despite what would be an acceptable training score, the high variance means we do not want to use this model.

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
X = df[clusters + seasons + basic_pos + created_cols]
y = df['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = RANDOM_STATE)

# %%
pipe = Pipeline([
    ('ss', StandardScaler()),
    ('svr', SVR())
])

pipe_params = {
    'ss__with_mean'  : [True],
    'ss__with_std'   : [False],
    'svr__shrinking' : [True],
    'svr__C'         : [1.0]
} 

svr = GridSearchCV(pipe, param_grid = pipe_params, cv = 3)

svr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('ss',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('svr',
#                                         SVR(C=1.0, cache_size=200, coef0=0.0,
#                                             degree=3, epsilon=0.1,
#                                             gamma='scale', kernel='rbf',
#                                             max_iter=-1, shrinking=True,
#                                             tol=0.001, verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'ss__with_mean': [True, False],
#                          'ss__with_std': [True, False],
# ...

# %%
print(f'Train Score:      {svr.score(X_train, y_train)}')
print(f'Test Score:       {svr.score(X_test, y_test)}')
print(f'Cross-Val Score:  {cross_val_score(svr, X, y).mean()}')
# Out:
# Train Score:      -0.20401474106886353
# Test Score:       -0.23991877541123707
# Cross-Val Score:  -0.20576036119217603

# %%
print(f'Train RMSE:      {get_rmse(svr, X_train, y_train)}')
print(f'Test RMSE:       {get_rmse(svr, X_test, y_test)}')
print(f'Cross-Val RMSE:  {round(cross_val_score(svr, X, y, cv = 5, scoring = make_scorer(rmse)).mean(), 2)}')
# Out:
# Train RMSE:      7809224.83
# Test RMSE:       8422557.34
# Cross-Val RMSE:  7895241.35

# %% [markdown]
# **Interpretation:** The Support Vector Machine is our worst model yet. This model not only has bias that is worse than our Baseline, but it also has high variance. While R2 score is not our official metric, we can see by looking at our R2 score that when putting our chosen features into a Support Vector Machine, they actually do worse job of explaining the variace in our target than just taking the mean of the target.

# %% [markdown]
# ## Model Selection

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# |**Model**|**Train RMSE**|**Test RMSE**|**Difference**|
# |:---|:---|:---|:---|
# |Ridge|4,395,017.13|4,662,334.2|267,317.07|
# |Linear Regression|4,415,305.36|4,738,569.1|323263.74|
# |Lasso|4,336,575.82|4,806,486.83|469,911.01|
# |Random Forest|2,551,553.13|4,859,316.6|2,307,763.47|
# |K Nearest Neighbors|0.0|5,147,463.72|5,147,463.72|
# |Decision Tree|4,353,970.1|5,242,285.06|888314.96|
# |Baseline|7,116,919.02|7,579,804.27|462885.25|
# |Support Vector Machine|7,809,224.83|8,422,557.34|613,332.51|

# %% [markdown]
# While each model that we have implemented predicts has high bias, with the exception of the Support Vector Machine, they all offer significant improvement over the baseline model which predicts mean.
#
# We will be implementing the Ridge model as it minimizes RMSE and has the lowest variance of all of the models that we have created.

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
figure, ax = plt.subplots(figsize = (20,12), nrows = 1, ncols = 2)

plt.suptitle('Predicted NBA Salary vs Actual Salary', size = 24)

xfit_0 = np.unique(ridge.predict(X_train_sc))
yfit_0 = np.poly1d(np.polyfit(ridge.predict(X_train_sc), y_train_r, 1))(np.unique(ridge.predict(X_train_sc)))

ax[0].scatter(ridge.predict(X_train_sc), y_train_r)
ax[0].set_xlabel('Predictions', size = 16)
ax[0].set_ylabel('Actual', size = 16)
ax[0].set_title('Training Predictions vs Actual Salary', size = 18)

ax[0].plot(xfit_0, yfit_0)
                   
ax[0].ticklabel_format(style='plain')

xfit_1 = np.unique(ridge.predict(X_test_sc))
yfit_1 = np.poly1d(np.polyfit(ridge.predict(X_test_sc), y_test_r, 1))(np.unique(ridge.predict(X_test_sc)))

ax[1].scatter(ridge.predict(X_test_sc), y_test_r)
ax[1].set_xlabel('Predictions', size = 16)
ax[1].set_ylabel('Actual', size = 16)
ax[1].set_title('Training Predictions vs Actual Salary', size = 18)

ax[1].plot(xfit_1, yfit_1)

ax[1].ticklabel_format(style='plain')

# %% [markdown]
# **Interpretation:** Here we can see that our Training and Testing Predictions are very similar to one another. What is interesting to note is that our model has increased accuracy and the highest actual values and towards the lowest actual values but greatly struggles with the actual values that are closer to the middle. This suggests that players with the lowest salaries and the highest salaries are more often paid in line with what their statistics suggest they are worth. While the contracts of players who are in the middle of the pack are more likely to be affected by things beyond the scope of on-court statistics such as a team's needs or salary cap situation. We can also see some players having a negative prediction for their salary - these are the lowest performing and least productive players.

# %%
resids = ridge.predict(X_test_sc) - y_test_r

# %% [markdown]
# **Interpretation:**

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(y_test_r, resids)

plt.xlabel('Actual Value', size = 14)
plt.ylabel('Residual', size = 14)

plt.ticklabel_format(style='plain', axis='x',useOffset=False)
plt.ticklabel_format(style='plain', axis='y',useOffset=False)

plt.hlines(y = 0, xmin = min(y_test_r), xmax = max(y_test_r), color = 'red')

plt.title('Actual Values vs Residuals', size = 20);

# %% [markdown]
# **Interpretation:** Here we can see the residuals of the predictions at each of the actual values. We do not have homoskedacity in our residuals. We can see that see that our residuals are more prondounced as we get to some of their highest salaries but our prediction is accurate at the highest salary. Many of the most significant residuals are predictions that underestimate the actual value of the Salary. We believe this is the result our model being trained on data that included high performing young players with lower salaries (Due to the previously mentioned league contract stipulations), leading to the model predicting many high performing older players as having lower Salaries than they actually do. To improve this in the future we may look to add data that provides greater contract and player context beyond what were able to do with our K-Means Clustering.

# %%
plt.figure(figsize = (8, 6))

sns.distplot(resids, bins = 18, kde = False)

plt.xlabel('Residual', size = 14)
plt.ylabel('Frequency', size = 14)

plt.ticklabel_format(style='plain', axis='x',useOffset=False)

plt.title('Distribution of Ridge Regression Residuals', size = 20);

# %% [markdown]
# **Interpretation:** Our residuals do have an a normal distribution and are left-skewed because of the previously mentioned tendency for our model to understimate our Target variable.

# %%
coef_df = pd.DataFrame((X_test_r.columns, ridge.coef_)).T

coef_df.rename(columns = {0: 'feature', 1: 'coefficient'}, inplace = True)

coef_df.sort_values(by = 'coefficient', ascending = False, inplace = True)

# %%
# Create a dataframe of the 10 highest coefficients
res_top_10 = coef_df.head(10).sort_values(by = 'coefficient', ascending = True).reset_index().drop(columns = 'index')

# Create a dataframe of the 10 lowest coefficients
res_low_10 = coef_df.tail(10).sort_values(by = 'coefficient', ascending = True).reset_index().drop(columns = 'index')

# %%
# Create a horizontalbar graph to compare the 10 highest and 10 lowest coefficients

plt.figure(figsize = (6, 8))

plt.barh(res_low_10['feature'],res_low_10['coefficient'], color = 'red')

plt.barh(res_top_10['feature'], res_top_10['coefficient'], color = 'blue')

plt.xlabel('Coefficient', size = 16)
plt.ylabel('Feature', size = 16)

ticks = [make_tick(stat) for stat in res_low_10['feature']] + [make_tick(stat) for stat in res_top_10['feature']] 

plt.yticks(np.arange(20), ticks)

plt.title('Highest and Lowest Coefficients for Predicting NBA Salary', size = 18);

# %% [markdown]
# **Interpretation:** Here we can see the top 10 highest and lowest coefficients of the 52 features used in our model. Our created `age_score` feature had was our greatest coefficient and For each unit that `age_score` increased, Salary increased by $3,232,871.86 (with all other factors being held equal). While our strongest negative coefficient was our created `point_share` features and for each unit that `point_share` increased Salary decreased by \\$2,668,660.15 with all other factors held equal. It is important to note that due to the nature of NBA statistics and the features in our model, increases in some of our positive coefficients would necessitate increases in some our negative coefficients, thus reducing their overall impact.

# %%
# Creating seperate dataframes for the positive and negative coefficients
neg_coef = coef_df[coef_df['coefficient'] < 0]
pos_coef = coef_df[coef_df['coefficient'] > 0]

# %%
pos_coef.shape
# Out:
# (29, 2)

# %%
neg_coef.shape
# Out:
# (23, 2)

# %% [markdown]
# 29 of the features in our final feature set have positive coeffiecients while 23 have negative coefficients.

# %% [markdown]
# ## Prediction Analysis

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %%
# Creating a scaled version of our entire dataframe of X
X_sc = ss.transform(X)

# Creating a prediction column for our entire dataframe
df['predicted'] = ridge.predict(X_sc)

df['predicted'] = round(df['predicted'], 2)

# Creating a residual column that shows the difference
# In predicted and actual Salary for each data point in our data frame
df['resid'] = df['salary'] - df['predicted']

# %%
sal_check = ['player','team_id', 'age', 'pts_per_g', 'salary']

check = ['player','team_id', 'age', 'pts_per_g', 'mp_per_g', 'salary', 'predicted', 'resid']

group_check = ['age', 'pts_per_g', 'salary', 'predicted', 'resid']

# %%
df[df['player'] == 'Gordon Hayward'][['g'] + check + seasons]
# Out:
#        g          player team_id  age  pts_per_g  mp_per_g    salary  \
# 449   73  Gordon Hayward     UTA   26  21.900000 34.500000  16073140
# 618    1  Gordon Hayward     BOS   27   2.000000  5.000000  29727900
# 1537  72  Gordon Hayward     BOS   28  11.500000 25.900000  31214295
#
#            predicted           resid  season_2017  season_2018  season_2019
# 449  14890273.330000  1182866.670000            1            0            0
# 618   1884748.950000 27843151.050000            0            1            0
# 1537 11844686.960000 19369608.040000            0            0            1

# %% [markdown]
# Here we can take a look at Gordon Hayward, our largest outlier mentioned at the beginning of the notebook. We see that based on our model's predictions he was highly overpaid in 2018 and 2019. However we know that his situation is due to suffering a season ending ankle injury in the 2018 season and still working to recover from that injury in the 2019 season. Hawyard's situation is one that goes beyond the realm of all on-court statistics and showcases one of the limitations of buidling a model using only a player's statistical output.

# %%
df[df['player'] == 'Draymond Green'][check + seasons]
# Out:
#               player team_id  age  pts_per_g  mp_per_g    salary  \
# 332   Draymond Green     GSW   26  10.200000 32.500000  15330435
# 925   Draymond Green     GSW   27  11.000000 32.700000  16400000
# 1558  Draymond Green     GSW   28   7.400000 31.300000  17469565
#
#            predicted          resid  season_2017  season_2018  season_2019
# 332  12415347.830000 2915087.170000            1            0            0
# 925  13637601.690000 2762398.310000            0            1            0
# 1558 12715912.460000 4753652.540000            0            0            1

# %% [markdown]
# Nex we can take a look at Draymond Green, a key figure in the Golden State Warriors' NBA Championship winning seasons in 2017 and 2018. Green is an example of a player that has tremendous on-court impact that is not reflected in traditional basketball statistics. Because of his perceived statistical limitations, our model is not able accurately predict the contract Green would be signed for and thus predicts him as overpaid.

# %%
df[df['player'] == 'DeMarcus Cousins'][check + seasons]
# Out:
#                 player team_id  age  pts_per_g  mp_per_g    salary  \
# 66    DeMarcus Cousins     SAC   26  27.800000 34.400000  15756438
# 84    DeMarcus Cousins     NOP   26  24.400000 33.800000  15756438
# 635   DeMarcus Cousins     NOP   27  25.200000 36.200000  18063850
# 1553  DeMarcus Cousins     GSW   28  16.300000 25.700000   5337000
#
#            predicted            resid  season_2017  season_2018  season_2019
# 66   23086878.090000  -7330440.090000            1            0            0
# 84   18042911.790000  -2286473.790000            1            0            0
# 635  27312045.200000  -9248195.200000            0            1            0
# 1553 15604517.810000 -10267517.810000            0            0            1

# %% [markdown]
# Here we have DeMarcus Cousins. Cousins' predicted contracted situation is a combination of multiple outside factors. While Cousins is a player with enormous statistical output which leads our model to predict that he would have a very high salary, his salary is much lower than expected because Cousins has been a player that is notoriously difficult to work with and has been known to be widely disliked around the league, limiting his market and reducing the amount that teams are willing to pay him. Second, Cousins was injured during the 2018 season, so he had very little power to negotiate his contract coming into the 2019 season - which led to him signing or a Salary that is much lower than what our model was able to predict.

# %%
df.sort_values(by = 'predicted').head()[check + seasons]
# Out:
#                  player team_id  age  pts_per_g  mp_per_g   salary  \
# 809  Antonius Cleveland     ATL   23   3.300000 10.500000   384116
# 722       Edmond Sumner     IND   22   2.000000  2.000000    77250
# 463   Demetrius Jackson     BOS   22   2.000000  3.400000  1450000
# 103        Axel Toupane     NOP   24   5.500000 20.500000   977534
# 225      Chasson Randle     PHI   23   5.300000  9.300000   541170
#
#           predicted          resid  season_2017  season_2018  season_2019
# 809 -2169882.830000 2553998.830000            0            1            0
# 722 -2085947.570000 2163197.570000            0            1            0
# 463 -1780774.170000 3230774.170000            1            0            0
# 103 -1741744.050000 2719278.050000            1            0            0
# 225 -1621217.970000 2162387.970000            1            0            0

# %% [markdown]
# Here we see the players with the lowest predicted Salaries in our entire data set. These players clearly have very low statistical production and impact and it is clear why they might be predicted to have a negative salary based on our features. It is important to note that of these players, only 3 are still in the NBA and only 1, Edmond Summer is currently on the same team as when he was predicted to have a negative salary.

# %%
# Created a function to map onto the DataFrame
# Returns 1 if player is overpaid and 0 if player is underpaid
def get_value(num):
    if num > 0:
        return 1
    if num < 0:
        return 0

# %%
df['value'] = df['resid'].map(get_value)

# %%
team_spend = round(df.groupby('team_id')[check + ['value']].mean().sort_values(by = 'resid', ascending = False), 2)

# %%
team_spend
# Out:
#               age  pts_per_g  mp_per_g         salary      predicted  \
# team_id
# POR     24.470000   8.830000 19.470000 7741971.130000 6169173.260000
# TOR     25.520000   8.130000 18.220000 7495336.480000 5969798.540000
# OKC     25.980000   7.750000 18.270000 7115557.380000 5918975.820000
# BOS     25.430000   8.200000 18.320000 6879873.180000 5764596.750000
# WAS     26.830000   8.510000 19.350000 7993600.240000 6878850.690000
# DET     25.980000   7.810000 18.460000 6849440.980000 5972817.690000
# CHO     25.780000   8.040000 18.970000 6920425.220000 6074925.970000
# MIL     26.340000   7.480000 17.430000 6300545.570000 5469152.260000
# CLE     28.220000   8.170000 18.940000 7447363.080000 6799857.900000
# ORL     24.800000   7.940000 19.160000 5822854.040000 5210164.430000
# UTA     26.500000   8.260000 18.890000 6166985.210000 5828018.350000
# MIN     26.460000   9.070000 20.490000 6801115.140000 6491364.540000
# ...

# %% [markdown]
# **Interpretation:** The Portland Trail Blazers are the most likely to overpay:
# Portland overpays players by \\$1,572,797.87 on average. 67\% of the players signed by Portland have contracts that exceed their statistical value.
#
# On the opposite end The Atlanta Hawks are the most likely to underpay: Atlanta players are underpaid by \\$947,813.93 on average 79\% of players signed by the Hawks are underpaid.

# %%
# Create dataframes for the NBA teams based on whether their average residual was positive or negative

pos_team = team_spend[team_spend['resid'] > 0].sort_values(by = 'resid', ascending = True)

neg_team = team_spend[team_spend['resid'] < 0].sort_values(by = 'resid', ascending = True)

# %%
plt.figure(figsize = (6, 8))

plt.barh(neg_team.index, neg_team['resid'], color = 'red')


plt.barh(pos_team.index, pos_team['resid'], color = 'blue')

plt.xlabel('Residual', size = 15)
plt.ylabel('Team', size = 18)

plt.title('Average Over-Pay and Under-Pay by Team', size = 16);

# %% [markdown]
# **Interpretation:** Here we can see that 18 teams overpay their players on average while 12 teams underpay their players on average, according to our model's predictions.
#
# One thing that is very important to note is that how much a team may overpay or underpay the players on it's team on average is not necessarily a good metric for how well the team is managed. For example, the Houston Rockets, New York Knicks, and Phoenix Suns pay their players closest to our models predictions on average, but the Rockets are generally seen to be one of the best managed teams in the NBA while the Knicks and Suns are seen as two of the worst.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# What we have found through the exploration of our data and the modeling process is that there is far more that influences an NBA player's salary than just raw statistical output, and the two sides have much more to discuss when at the negotiation table. However, when factors that are beyond the scope of on-court performance are limited and NBA contract policy does not artificially deflate a player's earning potential, machine learning can be a valuable tool to get an a rough estimate of what an NBA player should be paid, based on what he can contribute on the court over the course of a season. Thus, we believe that machine learning can be used by players and agents to set a starting point for salary negotiations and by General Managers to evaluate their own performance on player signings on a player-by-player basis.
#
# In the future, we hope to improve the depth of our analysis and our model's predictive capabilities by gathering more data and finding ways to add additional features that fully capture the context of each player's individual situation as well as the broader trends around the NBA. Eventually we would like to create a tool that will not only establish whether each player is generating a statistical output worthy of their contract, but that will also be able to accurately predict the value of future contracts based on past performance.

# %% [markdown]
# ## References

# %% [markdown]
# [(Table of Contents)](#Table-of-Contents)

# %% [markdown]
# [Salary Cap Information](http://www.cbafaq.com/salarycap.htm#Q16)
# [SuperMax Contract Effects](https://www.nbcsports.com/washington/wizards/explained-what-nba-supermax-contract-and-how-does-it-work#:~:text=What%20is%20a%20supermax%20contract,escalation%20in%20each%20subsequent%20year.)
# [Gordon Hayward's Injury](https://theundefeated.com/features/gordon-haywards-gruesome-injury-was-no-time-for-jokes-and-hot-takes/#:~:text=Hayward's%20injury%2C%20which%20has%20been,Paul%20George's%20tibia%2Dfibula%20fracture)
# [Draymond Green's Importance](https://www.goldenstateofmind.com/2020/5/5/21247371/greens-impact-on-basketball-equal-to-currys)
